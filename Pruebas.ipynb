# %%
from toolbox_ML import *

# %%
import pandas as pd

# %%
titanic = pd.read_csv('titanic.csv')

# %%
titanic.sample(5)
# Out:
#      survived  pclass     sex    age  sibsp  parch     fare embarked   class  \
# 432         1       2  female  42.00      1      0  26.0000        S  Second
# 806         0       1    male  39.00      0      0   0.0000        S   First
# 723         0       2    male  50.00      0      0  13.0000        S  Second
# 469         1       3  female   0.75      2      1  19.2583        C   Third
# 4           0       3    male  35.00      0      0   8.0500        S   Third
#
#        who  adult_male deck  embark_town alive  alone
# 432  woman       False  NaN  Southampton   yes  False
# 806    man        True    A  Southampton    no   True
# 723    man        True  NaN  Southampton    no   True
# 469  child       False  NaN    Cherbourg   yes  False
# 4      man        True  NaN  Southampton    no   True

# %%
display(describe_df(titanic))
# Out:
#               survived pclass     sex      age  sibsp  parch     fare  \
# DATA_TYPE        int64  int64  object  float64  int64  int64  float64
# MISSINGS(%)        0.0    0.0     0.0    19.87    0.0    0.0      0.0
# UNIQUE_VALUES        2      3       2       89      7      7      248
# CARDIN(%)         0.22   0.34    0.22     9.99   0.79   0.79    27.83
#
#               embarked   class     who adult_male    deck embark_town   alive  \
# DATA_TYPE       object  object  object       bool  object      object  object
# MISSINGS(%)       0.22     0.0     0.0        0.0   77.22        0.22     0.0
# UNIQUE_VALUES        4       3       3          2       8           4       2
# CARDIN(%)         0.45    0.34    0.34       0.22     0.9        0.45    0.22
#
#               alone
# DATA_TYPE      bool
# MISSINGS(%)     0.0
# UNIQUE_VALUES     2
# CARDIN(%)      0.22

# %%
display(tipifica_variables(titanic, 32.5, 10.0))
# Out:
# Error en la función tipifica_variable: El elemento introducido como umbral_categoria no es un int.
# None

# %%
display(tipifica_variables(titanic, 30, 10.0))
# Out:
#        variable      tipo_sugerido
# 0      survived            Binaria
# 1        pclass         Categórica
# 2           sex            Binaria
# 3           age  Numérica discreta
# 4         sibsp         Categórica
# 5         parch         Categórica
# 6          fare  Numérica discreta
# 7      embarked         Categórica
# 8         class         Categórica
# 9           who         Categórica
# 10   adult_male            Binaria
# 11         deck         Categórica
# 12  embark_town         Categórica
# 13        alive            Binaria
# 14        alone            Binaria

# %%
pepe = []

# %%
display(get_features_num_regression(data = pepe, umbral_corr= 1,target_col = 'age'))
# Out:
# Error en la función get_features_num_regression: El argumento "data" tiene que ser un Pandas DataFrame
# None

# %%
display(get_features_num_regression(data = titanic, umbral_corr= 1,target_col = 'age'))
# Out:
# ['survived', 'pclass', 'sibsp', 'parch', 'fare']

# %%
display(plot_features_num_regression(data = titanic, umbral_corr= 1,target_col = 'age'))
# Out:
# Index(['survived', 'pclass', 'sibsp', 'parch', 'fare'], dtype='object')
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')
# ['survived', 'pclass', 'sibsp', 'parch', 'fare']

# %%
get_features_cat_regression(data = titanic, target_col= 'age')
# Out:
# Error en la función get_feautures-cat_regression: El argumento introducido como target_col, no es una variable numérica discreta o contínua con alta cardinalidad

# %%
get_features_cat_regression(data = titanic, target_col= 'fare')
# Out:
#             Card     %_Card     Tipo   Clasificada_como
# survived       2   0.224467    int64            Binaria
# pclass         3     0.3367    int64         Categorica
# sex            2   0.224467   object            Binaria
# age           88   9.876543  float64  Numerica Discreta
# sibsp          7   0.785634    int64         Categorica
# parch          7   0.785634    int64         Categorica
# fare         248  27.833895  float64  Numerica Discreta
# embarked       3     0.3367   object         Categorica
# class          3     0.3367   object         Categorica
# who            3     0.3367   object         Categorica
# adult_male     2   0.224467     bool            Binaria
# deck           7   0.785634   object         Categorica
# embark_town    3     0.3367   object         Categorica
# alive          2   0.224467   object            Binaria
# alone          2   0.224467     bool            Binaria
# ...

# %%
display(plot_features_cat_regression(data = titanic, target_col= 'age', columns= ['pclass', 'sibsp', 'parch', 'embarked', 'class', 'who', 'deck', 'embark_town',
'survived', 'sex', 'adult_male', 'alive', 'alone']))
# Out:
#             Card    %_Card    Tipo Clasificada_como
# pclass         3    0.3367   int64       Categorica
# sibsp          7  0.785634   int64       Categorica
# parch          7  0.785634   int64       Categorica
# embarked       3    0.3367  object       Categorica
# class          3    0.3367  object       Categorica
# who            3    0.3367  object       Categorica
# deck           7  0.785634  object       Categorica
# embark_town    3    0.3367  object       Categorica
# survived       2  0.224467   int64          Binaria
# sex            2  0.224467  object          Binaria
# adult_male     2  0.224467    bool          Binaria
# alive          2  0.224467  object          Binaria
# alone          2  0.224467    bool          Binaria
# ['pclass', 'sibsp', 'parch', 'embarked', 'class', 'who', 'deck', 'embark_town']
# ['survived', 'sex', 'adult_male', 'alive', 'alone']
# Numerica Discreta
# {'adult_male': np.float64(0.9999999900051655),
# ...
